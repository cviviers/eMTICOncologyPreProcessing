# %%
import os
import xml.etree.ElementTree as ET
from utils.finder import find_leafes
from utils.dicom_to_nifti import seperate_labels, scan_only

# %%
directory = r'C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp'
annotation_dir = r'C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Detail annotaties\Detail Controle groep'
boundingbox_dir = r"C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Bounding boxes\BB Tumor(+), Vaat(+)"
output = r"C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data"

# %%
# pvp_descriptors = ['pvp', 'venus']
par_list = ['par', 'pan', '40']
pvp_list = ['ven', "pvp", "80", "port", "abdomen", "th abd ax 2 2"]
art_list = ['art']
liver_list = ['laat']
ct_list = ['ct', 'tho', 'thx', 'buik']
patient_cases = {}

# %%
for case in os.listdir(directory):
    
    if os.path.isdir(os.path.join(directory, case)):
        case_number = case

        # if int(case_number) < 1029:
        #     continue

        sectra = os.path.join(directory, case, "SECTRA", "CONTENT.XML")
        modalities = []
        if (os.path.exists(sectra)):
            root = ET.parse(sectra).getroot()
            print("==========================")
            print(case)
            print("==========================")
            for series in root.findall('patient/request/study/series'):
                for description in series.findall('series_data/description'):
                    print(series)
                    id = series.get('id')
                    print(id)
                    print(description.text)
                    phase = None

                    if description.text is not None:
                       
                        print("ct")
                        phase = "ct"
                        # if bool([ele for ele in par_list if(ele in description.text.lower())]):
                        #     print("PARENCHYMA")
                        #     phase = "par"
                        # if bool([ele for ele in pvp_list if(ele in description.text.lower())]):
                        #     print("PVP")
                        #     phase = "pvp"
                        # if bool([ele for ele in art_list if(ele in description.text.lower())]):
                        #     print("ART")
                        #     phase = "art"
                        # if bool([ele for ele in liver_list if(ele in description.text.lower())]):
                        #     print("liver")
                        #     phase = "liver"
                        # if bool([ele for ele in ct_list if(ele in description.text.lower())]):
                        #     print("ct")
                        #     phase = "ct"

                    elif description.text is None:
                        phase = "unknown"

                    modalities.append(phase)

                    if (phase == "unknown"):
                        continue
                    


                    high_data_dir = os.path.join(directory, case_number)
                    low_dir = find_leafes(high_data_dir)
                    data_dir = os.path.dirname(low_dir)

                    spec_data_dar = os.path.join(data_dir, id)
                    high_annotation_directory = os.path.join(annotation_dir, case_number)
                    spec_annotation_directory = find_leafes(high_annotation_directory)

                    if os.path.exists(spec_data_dar):
                        print(f"Data dir {spec_data_dar} found")
                    else:
                         print(f"Data dir {spec_data_dar} does not exist")

                    # if os.path.exists(spec_annotation_directory):
                    #     print(f"Annotation dir {spec_annotation_directory} found")
                    # else:
                    #      print(f"Annotation dir {spec_annotation_directory} does not exist")

                    
                    scan_only(spec_data_dar, output, case_number, phase)
                    
        else:

            print(f"{case} has an error")
            print(f"{sectra} does not exist")
            modalities.append("no info")
        patient_cases[case_number] = modalities
# Out:
# ==========================
# 1051
# ==========================
# <Element 'series' at 0x000001B974DADA40>
# 0000CA9F
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1051\DICOM\00001F85\AA0D90FF\AAC17405\0000CA9F found
# Reading: 1.3.46.670589.33.1.63742845791321250000009.4786786661173163554.2060.9512512
# reader
# itkSize3 ([512, 512, 1392])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 105
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97583A800)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 53
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1392]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1392]
#   Spacing: [0.679688, 0.679688, 0.45]
#   Origin: [-172.956, -39.7, 26.95]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.679688 0 0
# 0 0.679688 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.47126 0 0
# 0 1.47126 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BA60)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 45
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1051\ct\images\ct_1051.nii.gz
# ==========================
# 1052
# ==========================
# <Element 'series' at 0x000001B97838EC70>
# 00000872
# THORAX/BB 1/1 C
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1052\DICOM\0000B39B\AAD68BC7\AA2C77F1\00000872 found
# Reading: 1.2.840.113704.1.111.6676.1452435228.31.81.00512512
# reader
# itkSize3 ([512, 512, 436])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 42125
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97583A800)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 42073
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 436]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 436]
#   Spacing: [0.792969, 0.792969, 1]
#   Origin: [-204.779, -67.426, 271.5]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.792969 0 0
# 0 0.792969 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1.26108 0 0
# 0 1.26108 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B260)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 42065
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1052\ct\images\ct_1052.nii.gz
# ==========================
# 1053
# ==========================
# <Element 'series' at 0x000001B9342D86D0>
# 0000E50D
# THX/ABD PVP TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1053\DICOM\00000BEA\AA21F093\AA6F14F8\0000E50D found
# Reading: 1.3.46.670589.33.1.63732148380233246800009.4852764920028594849.2060.9512512
# reader
# itkSize3 ([512, 512, 1486])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 55465
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B922962020)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 55413
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1486]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1486]
#   Spacing: [0.746094, 0.746094, 0.45]
#   Origin: [-182.978, -69.2, 51.12]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.746094 0 0
# 0 0.746094 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.34031 0 0
# 0 1.34031 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B660)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 55405
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1053\ct\images\ct_1053.nii.gz
# ==========================
# 1054
# ==========================
# <Element 'series' at 0x000001B97F3BD130>
# 0000AD9E
# THO+ABD 1/1
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1054\DICOM\0000C7F1\AA09CED2\AA1790BF\0000AD9E found
# Reading: 1.2.840.113704.1.111.3992.1469103613.17.41.00512512
# reader
# itkSize3 ([512, 512, 676])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 100305
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9AB9EF7E0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 100253
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 676]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 676]
#   Spacing: [0.804688, 0.804688, 1]
#   Origin: [-205, -69, 6.20001]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.804688 0 0
# 0 0.804688 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1.24272 0 0
# 0 1.24272 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B360)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 100245
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1054\ct\images\ct_1054.nii.gz
# ==========================
# 1055
# ==========================
# <Element 'series' at 0x000001B97F3FB0E0>
# 00001350
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1055\DICOM\000032EC\AAA0C9C1\AAD6B461\00001350 found
# Reading: 1.3.46.670589.33.1.63635273878002608800005.5225194434783894436.2060.9512512
# reader
# itkSize3 ([512, 512, 1385])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 120845
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CAC90)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 120793
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1385]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1385]
#   Spacing: [0.679688, 0.679688, 0.449993]
#   Origin: [-183.048, -44.9, -1.11]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.679688 0 0
# 0 0.679688 0
# 0 0 0.449993
#
#   PointToIndexMatrix:
# 1.47126 0 0
# 0 1.47126 0
# 0 0 2.22226
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A9E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 120785
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1055\ct\images\ct_1055.nii.gz
# ==========================
# 1056
# ==========================
# <Element 'series' at 0x000001B9873166D0>
# 00003C3E
# None
# <Element 'series' at 0x000001B9873162C0>
# 000055F2
# Abdomen  2.0  B31f
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1056\DICOM\000036B7\AA21AFC6\AA29479D\000055F2 found
# Reading: 1.3.12.2.1107.5.1.4.50337.30000015120407200490600004244.82512512
# reader
# itkSize3 ([512, 512, 250])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 162655
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B977956970)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 162603
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 250]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 250]
#   Spacing: [0.742188, 0.742188, 2]
#   Origin: [-192.629, -373.629, -869.3]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.742188 0 0
# 0 0.742188 0
# 0 0 2
#
#   PointToIndexMatrix:
# 1.34737 0 0
# 0 1.34737 0
# 0 0 0.5
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BF60)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 162595
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1056\ct\images\ct_1056.nii.gz
# ==========================
# 1057
# ==========================
# <Element 'series' at 0x000001B974D2C360>
# 0000F359
# 2.5 THORAX/ABDOMEN
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1057\DICOM\00009936\AA8166E0\AA0849A9\0000F359 found
# Reading: 1.2.840.113619.2.327.3.2047475970.745.1446567389.373.22.500000512512
# reader
# itkSize3 ([512, 512, 246])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 170415
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E5870)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 170363
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 246]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 246]
#   Spacing: [0.851562, 0.851562, 2.5]
#   Origin: [-206.9, -195.8, -585]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.851562 0 0
# 0 0.851562 0
# 0 0 2.5
#
#   PointToIndexMatrix:
# 1.17431 0 0
# 0 1.17431 0
# 0 0 0.4
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B8E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 170355
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1057\ct\images\ct_1057.nii.gz
# ==========================
# 1058
# ==========================
# <Element 'series' at 0x000001B98730B5E0>
# 0000E1A9
# Abd Portaal  3.0  I30f  3
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1058\DICOM\000005BA\AA156435\AA250506\0000E1A9 found
# Reading: 1.3.12.2.1107.5.1.4.74913.30000015122804291134700052159.83512512
# reader
# itkSize3 ([512, 512, 140])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 178055
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E2380)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 178003
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 140]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 140]
#   Spacing: [0.660156, 0.660156, 3]
#   Origin: [-175.67, -291.67, 1352.4]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.660156 0 0
# 0 0.660156 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.51479 0 0
# 0 1.51479 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768ACE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 177995
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1058\ct\images\ct_1058.nii.gz
# ==========================
# 1059
# ==========================
# <Element 'series' at 0x000001B974C1F3B0>
# 0000893B
# None
# <Element 'series' at 0x000001B974C1F040>
# 0000161B
# ABD PORT 0.9/0.7
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1059\DICOM\000085A7\AA74DAF5\AA33371A\0000161B found
# Reading: 1.2.840.113704.1.111.2264.1453202749.41.90.90512512
# reader
# itkSize3 ([512, 512, 636])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 182515
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E50F0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 182463
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 636]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 636]
#   Spacing: [0.619141, 0.619141, 0.7]
#   Origin: [-168.174, -20.8684, 44.9]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.619141 0 0
# 0 0.619141 0
# 0 0 0.7
#
#   PointToIndexMatrix:
# 1.61514 0 0
# 0 1.61514 0
# 0 0 1.42857
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B960)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 182455
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1059\ct\images\ct_1059.nii.gz
# ==========================
# 1060
# ==========================
# <Element 'series' at 0x000001B974B86590>
# 0000A911
# THX TS B, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1060\DICOM\00008D5C\AA6263A0\AA3A0E5A\0000A911 found
# Reading: 1.3.46.670589.33.1.63605642661008047500010.4687884546895706204.2070.9512512
# reader
# itkSize3 ([512, 512, 972])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 201855
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E2680)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 201803
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 972]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 972]
#   Spacing: [0.683594, 0.683594, 0.45001]
#   Origin: [-185.85, -58.1, 138.35]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.683594 0 0
# 0 0.683594 0
# 0 0 0.45001
#
#   PointToIndexMatrix:
# 1.46286 0 0
# 0 1.46286 0
# 0 0 2.22217
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B4E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 201795
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1060\ct\images\ct_1060.nii.gz
# ==========================
# 1061
# ==========================
# <Element 'series' at 0x000001B974B86C70>
# 0000DB47
# TH/ABD ABC, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1061\DICOM\0000F1F9\AA6040EC\AA92356A\0000DB47 found
# Reading: 1.3.46.670589.33.1.63603827747347686400005.5175500869202921474.2040.9512512
# reader
# itkSize3 ([512, 512, 1525])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 231275
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E50F0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 231223
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1525]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1525]
#   Spacing: [0.802734, 0.802734, 0.45]
#   Origin: [-233.448, -109.3, 103.9]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.802734 0 0
# 0 0.802734 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.24574 0 0
# 0 1.24574 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BDE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 231215
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1061\ct\images\ct_1061.nii.gz
# ==========================
# 1062
# ==========================
# <Element 'series' at 0x000001B9763395E0>
# 000074F7
# THX/ABD TS
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1062\DICOM\00007FB2\AAC6A587\AAD1D640\000074F7 found
# Reading: 1.2.840.113704.1.111.4080.1523437263.17.41.00512512
# reader
# itkSize3 ([512, 512, 691])
# Image (000001B9759146C0)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 277285
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97C471D90)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 277233
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 691]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 691]
#   Spacing: [0.742188, 0.742188, 1]
#   Origin: [-198.364, -39, 35.6]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.742188 0 0
# 0 0.742188 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1.34737 0 0
# 0 1.34737 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BDE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 277225
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1062\ct\images\ct_1062.nii.gz
# ==========================
# 1063
# ==========================
# <Element 'series' at 0x000001B933329EF0>
# 00003070
# ABD PORT 0.9/0.7
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1063\DICOM\0000905A\AA0F3FF7\AAEDAFE7\00003070 found
# Reading: 1.2.840.113704.1.111.4856.1466066454.24.70.90512512
# reader
# itkSize3 ([512, 512, 629])
# Image (000001B9759143F0)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 298275
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97BAAD580)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 298223
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 629]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 629]
#   Spacing: [0.759766, 0.759766, 0.7]
#   Origin: [-201.218, -60.3472, 47.4]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.759766 0 0
# 0 0.759766 0
# 0 0 0.7
#
#   PointToIndexMatrix:
# 1.3162 0 0
# 0 1.3162 0
# 0 0 1.42857
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A660)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 298215
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1063\ct\images\ct_1063.nii.gz
# ==========================
# 1064
# ==========================
# <Element 'series' at 0x000001B9873E7E50>
# 000007D4
# 2.5 THORAX/ABDOMEN
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1064\DICOM\0000D483\AA49F6AA\AAE81B6A\000007D4 found
# Reading: 1.2.840.113619.2.398.3.2047476226.967.1467125647.560.52.500000512512
# reader
# itkSize3 ([512, 512, 249])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 317405
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CA690)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 317353
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 249]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 249]
#   Spacing: [0.703125, 0.703125, 2.5]
#   Origin: [-180, -178.4, -599]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.703125 0 0
# 0 0.703125 0
# 0 0 2.5
#
#   PointToIndexMatrix:
# 1.42222 0 0
# 0 1.42222 0
# 0 0 0.4
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BEE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 317345
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1064\ct\images\ct_1064.nii.gz
# ==========================
# 1065
# ==========================
# <Element 'series' at 0x000001B9784249F0>
# 000000EA
# THO/ABD 80SEC PI, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1065\DICOM\0000E8F2\AA18EDCD\AAF98645\000000EA found
# Reading: 1.3.46.670589.33.1.63601085559216931600001.5184406736876828715.3013512512
# reader
# itkSize3 ([512, 512, 209])
# Image (000001B9759146C0)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 325135
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97567F220)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 325083
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 209]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 209]
#   Spacing: [0.769531, 0.769531, 3]
#   Origin: [-219.064, -135.488, -752.21]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.769531 0 0
# 0 0.769531 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.29949 0 0
# 0 1.29949 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A4E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 325075
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1065\ct\images\ct_1065.nii.gz
# ==========================
# 1066
# ==========================
# <Element 'series' at 0x000001B974C9AEA0>
# 0000C81C
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1066\DICOM\00002934\AA4E69A6\AA976ABE\0000C81C found
# Reading: 1.3.46.670589.33.1.63605907863883869100009.4676851426318556049.2060.9512512
# reader
# itkSize3 ([512, 512, 1379])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 331665
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E56F0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 331613
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1379]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1379]
#   Spacing: [0.761719, 0.761719, 0.449993]
#   Origin: [-198.12, -81.45, -0.28]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.761719 0 0
# 0 0.761719 0
# 0 0 0.449993
#
#   PointToIndexMatrix:
# 1.31282 0 0
# 0 1.31282 0
# 0 0 2.22226
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B260)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 331605
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1066\ct\images\ct_1066.nii.gz
# ==========================
# 1067
# ==========================
# <Element 'series' at 0x000001B987306C70>
# 0000D2CD
# THX/ABD PVP TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1067\DICOM\0000DAA3\AA458F02\AA30807B\0000D2CD found
# Reading: 1.3.46.670589.33.1.63672884909275142700003.4807507663868548079.2060.9512512
# reader
# itkSize3 ([512, 512, 1345])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 373295
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CB110)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 373243
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1345]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1345]
#   Spacing: [0.683594, 0.683594, 0.45]
#   Origin: [-171.85, -67.5, -44.66]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.683594 0 0
# 0 0.683594 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.46286 0 0
# 0 1.46286 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B360)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 373235
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1067\ct\images\ct_1067.nii.gz
# ==========================
# 1068
# ==========================
# <Element 'series' at 0x000001B974D99720>
# 00001F42
# THO/ABD 80s PI
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1068\DICOM\0000E0B2\AA730F9C\AAEB4F73\00001F42 found
# Reading: 1.2.840.113704.1.111.4064.1469532747.24.53.00512512
# reader
# itkSize3 ([512, 512, 205])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 413905
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97BAAD280)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 413853
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 205]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 205]
#   Spacing: [0.880859, 0.880859, 3]
#   Origin: [-229.5, -130.5, -794]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.880859 0 0
# 0 0.880859 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.13525 0 0
# 0 1.13525 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A260)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 413845
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1068\ct\images\ct_1068.nii.gz
# ==========================
# 1069
# ==========================
# <Element 'series' at 0x000001B98E329360>
# 0000CEC2
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1069\DICOM\0000E9BD\AAF910D7\AA4B1030\0000CEC2 found
# Reading: 1.3.46.670589.33.1.63610045372893767600004.4865150035231204541.3060.9512512
# reader
# itkSize3 ([512, 512, 1485])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 420315
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E56F0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 420263
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1485]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1485]
#   Spacing: [0.744141, 0.744141, 0.45]
#   Origin: [-190.5, -48.193, -786.38]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.744141 0 0
# 0 0.744141 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.34383 0 0
# 0 1.34383 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B8E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 420255
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1069\ct\images\ct_1069.nii.gz
# ==========================
# 1070
# ==========================
# <Element 'series' at 0x000001B98E32D5E0>
# 00002914
# 2.5 THORAX/ABDOMEN
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1070\DICOM\00000A02\AA30E7DF\AA0E295C\00002914 found
# Reading: 1.2.840.113619.2.327.3.2047475970.241.1476458543.51.22.500000512512
# reader
# itkSize3 ([512, 512, 240])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 465125
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B97BAADA00)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 465073
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 240]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 240]
#   Spacing: [0.738281, 0.738281, 2.5]
#   Origin: [-185.5, -189, -578.5]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.738281 0 0
# 0 0.738281 0
# 0 0 2.5
#
#   PointToIndexMatrix:
# 1.3545 0 0
# 0 1.3545 0
# 0 0 0.4
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BB60)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 465065
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1070\ct\images\ct_1070.nii.gz
# ==========================
# 1071
# ==========================
# <Element 'series' at 0x000001B987306DB0>
# 00003AC7
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1071\DICOM\000043A1\AA67646E\AAF30AB5\00003AC7 found
# Reading: 1.3.46.670589.33.1.63622254360379677700008.5234873277930438011.2060.9512512
# reader
# itkSize3 ([512, 512, 1479])
# Image (000001B9759143F0)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 472585
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E5270)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 472533
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1479]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1479]
#   Spacing: [0.853516, 0.853516, 0.45]
#   Origin: [-225.492, -83.7, -3.61]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.853516 0 0
# 0 0.853516 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.17162 0 0
# 0 1.17162 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BAE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 472525
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1071\ct\images\ct_1071.nii.gz
# ==========================
# 1072
# ==========================
# <Element 'series' at 0x000001B933273360>
# 00007CE9
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1072\DICOM\00008E46\AA689656\AA529BD4\00007CE9 found
# Reading: 1.3.46.670589.33.1.63633832656728010000004.5755882438043480402.2060.9512512
# reader
# itkSize3 ([512, 512, 1539])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 517215
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B904041C10)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 517163
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1539]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1539]
#   Spacing: [0.816406, 0.816406, 0.45]
#   Origin: [-213.18, -107.2, -1.07]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.816406 0 0
# 0 0.816406 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.22488 0 0
# 0 1.22488 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A460)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 517155
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1072\ct\images\ct_1072.nii.gz
# ==========================
# 1073
# ==========================
# <Element 'series' at 0x000001B97F3AF720>
# 00001182
# 2.5 THORAX/ABDOMEN
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1073\DICOM\0000F18A\AA2B900A\AAB7FB27\00001182 found
# Reading: 1.2.840.113619.2.327.3.2047475970.520.1481037441.725.22.500000512512
# reader
# itkSize3 ([512, 512, 248])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 563645
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CA510)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 563593
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 248]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 248]
#   Spacing: [0.738281, 0.738281, 2.5]
#   Origin: [-189, -184.1, -589.5]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.738281 0 0
# 0 0.738281 0
# 0 0 2.5
#
#   PointToIndexMatrix:
# 1.3545 0 0
# 0 1.3545 0
# 0 0 0.4
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A3E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 563585
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1073\ct\images\ct_1073.nii.gz
# ==========================
# 1074
# ==========================
# <Element 'series' at 0x000001B991359270>
# 00004490
# THX/ABD TS
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1074\DICOM\0000F557\AA23A5B6\AAE4D607\00004490 found
# Reading: 1.2.840.113704.1.111.7188.1538995656.25.61.00512512
# reader
# itkSize3 ([512, 512, 618])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 571345
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B916CB1790)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 571293
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 618]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 618]
#   Spacing: [0.646484, 0.646484, 1]
#   Origin: [-186.5, 3.5, -779.1]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.646484 0 0
# 0 0.646484 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1.54683 0 0
# 0 1.54683 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BDE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 571285
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1074\ct\images\ct_1074.nii.gz
# ==========================
# 1075
# ==========================
# <Element 'series' at 0x000001B991360400>
# 00004ED1
# None
# <Element 'series' at 0x000001B991359F90>
# 00009CA3
# THO/ABD 80SEC PI, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1075\DICOM\0000CF67\AA0CCCD4\AA0D4235\00009CA3 found
# Reading: 1.3.46.670589.33.1.63621450804097708800001.5273331326970830940.8013512512
# reader
# itkSize3 ([512, 512, 226])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 590145
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9826150F0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 590093
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 226]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 226]
#   Spacing: [0.845703, 0.845703, 3]
#   Origin: [-215.634, -71.379, 117.73]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.845703 0 0
# 0 0.845703 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.18245 0 0
# 0 1.18245 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A9E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 590085
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1075\ct\images\ct_1075.nii.gz
# ==========================
# 1076
# ==========================
# <Element 'series' at 0x000001B991360C20>
# 00004F7F
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1076\DICOM\000051F4\AA40479F\AAA5C7B7\00004F7F found
# Reading: 1.3.46.670589.33.1.63633091506909486900009.5392622304763796214.2060.9512512
# reader
# itkSize3 ([512, 512, 1445])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 597185
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B915DE3820)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 597133
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1445]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1445]
#   Spacing: [0.917969, 0.917969, 0.45]
#   Origin: [-237.82, -152.14, 351.82]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.917969 0 0
# 0 0.917969 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.08936 0 0
# 0 1.08936 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A1E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 597125
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1076\ct\images\ct_1076.nii.gz
# ==========================
# 1077
# ==========================
# <Element 'series' at 0x000001B9763348B0>
# 000099EB
# THOR/ABD 3/3, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1077\DICOM\0000084B\AA3263D7\AAB59D75\000099EB found
# Reading: 1.3.46.670589.33.1.63621367701434051100001.5506516285180428120.3013512512
# reader
# itkSize3 ([512, 512, 205])
# Image (000001B975913E50)
# ...
# reader
# itkSize3 ([512, 512, 1552])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 839355
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9788B9AA0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 839303
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1552]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1552]
#   Spacing: [0.808594, 0.808594, 0.45]
#   Origin: [-204.102, -82.6, -850.1]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.808594 0 0
# 0 0.808594 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.23671 0 0
# 0 1.23671 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B8E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 839295
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1090\ct\images\ct_1090.nii.gz
# ==========================
# 1091
# ==========================
# <Element 'series' at 0x000001B977373900>
# 0000ACD5
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1091\DICOM\0000BB70\AA775EB8\AA4E0C7E\0000ACD5 found
# Reading: 1.3.46.670589.33.1.63673548117495586500009.4854989049973713376.2060.9512512
# reader
# itkSize3 ([512, 512, 1519])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 886175
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9339E1F00)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 886123
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1519]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1519]
#   Spacing: [0.771484, 0.771484, 0.45]
#   Origin: [-203.425, -48.19, 15.37]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.771484 0 0
# 0 0.771484 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.2962 0 0
# 0 1.2962 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768BA60)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 886115
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1091\ct\images\ct_1091.nii.gz
# ==========================
# 1092
# ==========================
# <Element 'series' at 0x000001B978404310>
# 0000151E
# THX/ABD TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1092\DICOM\00000303\AA2B602B\AAA53997\0000151E found
# Reading: 1.3.46.670589.33.1.63637798710461657700003.5760520705038471531.5060.9512512
# reader
# itkSize3 ([512, 512, 1539])
# Image (000001B9759143F0)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 932005
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CB290)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 931953
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1539]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1539]
#   Spacing: [0.783203, 0.783203, 0.45]
#   Origin: [-216.54, -77.3, 57.53]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.783203 0 0
# 0 0.783203 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.27681 0 0
# 0 1.27681 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B660)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 931945
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1092\ct\images\ct_1092.nii.gz
# ==========================
# 1093
# ==========================
# <Element 'series' at 0x000001B974D9BA40>
# 00000C67
# Abd Portaal  3.0  I30f  3
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1093\DICOM\00004AC7\AA158C10\AA6B2C99\00000C67 found
# Reading: 1.3.12.2.1107.5.1.4.74913.30000017111007111067600012885.83512512
# reader
# itkSize3 ([512, 512, 140])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 978435
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B975683890)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 978383
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 140]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 140]
#   Spacing: [0.726563, 0.726563, 3]
#   Origin: [-186.637, -346.137, 1198.2]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.726563 0 0
# 0 0.726563 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.37634 0 0
# 0 1.37634 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768AA60)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 978375
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1093\ct\images\ct_1093.nii.gz
# ==========================
# 1094
# ==========================
# <Element 'series' at 0x000001B9332A5590>
# 0000B9D6
# THA AX 2 2
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1094\DICOM\0000C0AF\AA38004C\AA208FC7\0000B9D6 found
# Reading: 1.2.840.113619.2.5.166636385.11120.1514358924.400.6030.876953512512
# reader
# itkSize3 ([512, 512, 1])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 982892
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CA990)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 982843
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1]
#   Spacing: [1.68945, 1.68945, 1]
#   Origin: [-427.799, 14.031, -22.502]
#   Direction:
# 1 0 0
# 0 0 1
# 0 -1 0
#
#   IndexToPointMatrix:
# 1.68945 0 0
# 0 0 1
# 0 -1.68945 0
#
#   PointToIndexMatrix:
# 0.591908 0 0
# 0 0 -0.591908
# 0 1 0
#
#   Inverse Direction:
# 1 0 0
# 0 0 -1
# 0 1 0
#
#   PixelContainer:
#     ImportImageContainer (000001B97768AEE0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 982835
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# ==========================
# 1095
# ==========================
# <Element 'series' at 0x000001B9783CEA90>
# 00003D79
# THO/ABD 80SEC PI, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1095\DICOM\0000C810\AADA0EDD\AAFB3C7C\00003D79 found
# Reading: 1.3.46.670589.33.1.63649376246501397500001.4873384044348152255.3013512512
# reader
# itkSize3 ([512, 512, 199])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 982961
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CA690)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 982909
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 199]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 199]
#   Spacing: [0.683594, 0.683594, 3]
#   Origin: [-175, -46.2, 51.63]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.683594 0 0
# 0 0.683594 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.46286 0 0
# 0 1.46286 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768A6E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 982901
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1095\ct\images\ct_1095.nii.gz
# ==========================
# 1096
# ==========================
# <Element 'series' at 0x000001B978423E00>
# 00004A14
# ABD PVP TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1096\DICOM\000026F8\AAED76A9\AA407226\00004A14 found
# Reading: 1.3.46.670589.33.1.63667342130972659800002.5629655809397880889.7040.9512512
# reader
# itkSize3 ([512, 512, 892])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 989191
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9779EFFA0)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 989139
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 892]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 892]
#   Spacing: [0.640625, 0.640625, 0.45]
#   Origin: [-171.872, -49.488, 16.26]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.640625 0 0
# 0 0.640625 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.56098 0 0
# 0 1.56098 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B760)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 989131
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1096\ct\images\ct_1096.nii.gz
# ==========================
# 1097
# ==========================
# <Element 'series' at 0x000001B974C70770>
# 00002AD3
# THOR/ABD 3/3, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1097\DICOM\00001440\AAFEA764\AACF9965\00002AD3 found
# Reading: 1.3.46.670589.33.1.63630091379234324100001.4648147352351568062.3013512512
# reader
# itkSize3 ([512, 512, 222])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 1016211
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9750CA690)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 1016159
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 222]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 222]
#   Spacing: [0.830078, 0.830078, 3]
#   Origin: [-209.525, -109.6, 48.64]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.830078 0 0
# 0 0.830078 0
# 0 0 3
#
#   PointToIndexMatrix:
# 1.20471 0 0
# 0 1.20471 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B8E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 1016151
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1097\ct\images\ct_1097.nii.gz
# ==========================
# 1098
# ==========================
# <Element 'series' at 0x000001B9332A5860>
# 0000478C
# THX/ABD PVP TS, iDose (3)
# ct
# Data dir C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\CT scans\CT scans controle groep\temp\1098\DICOM\000087A6\AAA86198\AA0E7BCE\0000478C found
# Reading: 1.3.46.670589.33.1.63647553671789536400007.5473875633370108877.2060.9512512
# reader
# itkSize3 ([512, 512, 1479])
# Image (000001B975913E50)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 2
#   Modified Time: 1023131
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (000001B9788B9C20)
#   Source output name: Primary
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 1023079
#   UpdateMTime: 0
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1479]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [0, 0, 0]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [512, 512, 1479]
#   Spacing: [0.769531, 0.769531, 0.45]
#   Origin: [-226.156, -77.136, 69.38]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.769531 0 0
# 0 0.769531 0
# 0 0 0.45
#
#   PointToIndexMatrix:
# 1.29949 0 0
# 0 1.29949 0
# 0 0 2.22222
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (000001B97768B8E0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 1023071
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000000000000000
#       Container manages memory: true
#       Size: 0
#       Capacity: 0
#
# metadata:  Dictionary use_count: 1
#
# Writing: C:\Users\320088652\OneDrive - Philips\TUe\eMTIC\Pancreas_BB\Pancreas_BB\Processed_Data\1098\ct\images\ct_1098.nii.gz

# %%
patient_cases
