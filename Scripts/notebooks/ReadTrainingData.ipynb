# %%
import pickle

# %%
file_pkl = r"/home/chris/Data/Projects/eMTIC/nnUNet/data/nnUnet_preprocessed/Task001_Segmentation/dataset_properties.pkl"

# %%
with open(file_pkl, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#                                  ('par_1059',
#                                            OrderedDict([('median', 93.0),
#                                                         ('mean', 92.55884),
#                                                         ('sd', 62.39578),
#                                                         ('mn', -162.0),
#                                                         ('mx', 617.0),
#                                                         ('percentile_99_5',
#                                                          232.0),
#                                                         ('percentile_00_5',
#                                                          -82.0)])),
#                                           ('par_1060',
#                                            OrderedDict([('median', 106.0),
#                                                         ('mean', 121.33979),
# ...

# %%
splits_pkl = r"/home/chris/Data/Projects/eMTIC/nnUNet/data/nnUnet_preprocessed/Task001_Segmentation/splits_final.pkl"

# %%
with open(splits_pkl, 'rb') as f:
    splits_data = pickle.load(f)

# %%
splits_data
# Out:
# [OrderedDict([('train',
#                array(['par_1052', 'par_1055', 'par_1057', 'par_1058', 'par_1059',
#                       'par_1060', 'par_1062', 'par_1063', 'par_1064', 'par_1067',
#                       'par_1068', 'par_1070', 'par_1072', 'par_1074', 'par_1076',
#                       'par_1080', 'par_1082', 'par_1083', 'par_1084', 'par_1088',
#                       'par_1089', 'par_1091', 'par_1092', 'par_1099', 'par_1100'],
#                      dtype='<U8')),
#               ('val',
#                array(['par_1051', 'par_1056', 'par_1061', 'par_1066', 'par_1069',
#                       'par_1073', 'par_1090'], dtype='<U8'))]),
#  OrderedDict([('train',
#                array(['par_1051', 'par_1052', 'par_1055', 'par_1056', 'par_1057',
#                       'par_1058', 'par_1061', 'par_1062', 'par_1063', 'par_1064',
#                       'par_1066', 'par_1067', 'par_1068', 'par_1069', 'par_1070',
# ...

# %%
plan_pkl = r"/home/chris/Data/Projects/eMTIC/nnUNet/data/nnUnet_preprocessed/Task001_Segmentation/nnUNetPlansv2.1_plans_3D.pkl"

# %%
with open(plan_pkl, 'rb') as f:
    plan_data = pickle.load(f)

# %%
plan_data
# Out:
#          ('percentile_99_5',
#                                                           395.0),
#                                                          ('percentile_00_5',
#                                                           -13.0)])),
#                                            ('par_1072',
#                                             OrderedDict([('median', 118.0),
#                                                          ('mean', 123.699326),
#                                                          ('sd', 93.13882),
#                                                          ('mn', -209.0),
#                                                          ('mx', 1254.0),
#                                                          ('percentile_99_5',
#                                                           444.0),
#                                                          ('percentile_00_5',
#                                                           -93.0)])),
# ...
