# %%
import json

# %%
tumour_list = []
pancrea_list = []
with open('summary20210322_cascaded.json') as json_file:
    data = json.load(json_file)
    for count, value in enumerate(data['results']['all']):
        print("Pancreas")
        print(value["1"])
        pancrea_list.append(value["1"]['Dice'])
        print("Tumour")
        print(value["2"])
        tumour_list.append(value["2"]['Dice'])
# Out:
# Pancreas
# {'Accuracy': 0.9991304714048924, 'Dice': 0.8039661083622256, 'False Discovery Rate': 0.28369583891695016, 'False Negative Rate': 0.08392364345854353, 'False Omission Rate': 0.00016375535461059983, 'False Positive Rate': 0.0007075580437722051, 'Jaccard': 0.6721934169117267, 'Negative Predictive Value': 0.9998362446453894, 'Precision': 0.7163041610830498, 'Recall': 0.9160763565414565, 'Total Positives Reference': 113782, 'Total Positives Test': 145515, 'True Negative Rate': 0.9992924419562278}
# Tumour
# ...

# %%
print(tumour_list)
# Out:
# [0.7563078134225546, 0.06974944950306493, 0.03627760252365931, 0.0, 0.668263914485809, 0.7932578351329997, 0.1787376652392478, 0.69631724403882, 0.0, 0.6908968695986173, 0.6759780418317004, 0.8638888888888889, 0.3573458544421105, 0.0006591378476952147, 0.4931426561950533, 0.4693371144984048, 0.0, 0.017255110167241836, 0.0, 0.012337545666886267, 0.007071653744568459, 0.021049809661680338, 0.0826783709298765, 0.0, 0.8009113512389272, 0.006743355811186037, 0.0, 0.0, 0.6913547355801252, 0.2961490024524425, 0.8419895110810354, 0.0]

# %%
print(pancrea_list)
# Out:
# [0.8039661083622256, 0.8369342024514438, 0.8360594237695078, 0.6644363198046807, 0.8884155479401808, 0.7951121059777623, 0.8838306512553965, 0.8318441300570861, 0.9433569995109364, 0.8894932848513284, 0.8021583187302228, 0.8310059561257548, 0.8134375216362625, 0.7684330551742286, 0.8367662600345742, 0.7601774332732806, 0.8573378379246337, 0.8503222667628799, 0.8839006952262677, 0.8162249060953354, 0.8591844462895059, 0.7796913515857896, 0.8284420644113178, 0.8265060960140872, 0.8326839918836254, 0.7905511377706849, 0.7791656846570822, 0.8729199540256755, 0.8541577187747742, 0.8399089944917719, 0.8378127258336487, 0.7602333248795333]
